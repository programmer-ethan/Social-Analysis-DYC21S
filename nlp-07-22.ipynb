# %%
from konlpy.tag import Hannanum

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
kkma.sentences('한국어 분석. 시작합니다. 그렇습니다.')
# Out:
# ['한국어 분석. 시작합니다.', '그렇습니다.']

# %%
kkma.nouns('한국어 분석. 시작합니다. 그렇습니다.')
# Out:
# ['한국어', '분석']

# %%
kkma.pos('한국어 분석. 시작합니다. 그렇습니다.')
# Out:
# [('한국어', 'NNG'),
#  ('분석', 'NNG'),
#  ('.', 'SF'),
#  ('시작하', 'VV'),
#  ('ㅂ니다', 'EFN'),
#  ('.', 'SF'),
#  ('그렇', 'VV'),
#  ('습니다', 'EFN'),
#  ('.', 'SF')]

# %%
from konlpy.tag import Hannanum
hannanum = Hannanum()
hannanum.nouns('한국어 분석. 시작합니다. 그렇습니다.')
hannanum.morphs('한국어 분석. 시작합니다. 그렇습니다.')
hannanum.pos('한국어 분석. 시작합니다. 그렇습니다.')
# Out:
# [('한국어', 'N'),
#  ('분석', 'N'),
#  ('.', 'S'),
#  ('시작', 'N'),
#  ('하', 'X'),
#  ('ㅂ니다', 'E'),
#  ('.', 'S'),
#  ('그렇', 'P'),
#  ('습니다', 'E'),
#  ('.', 'S')]

# %%
from konlpy.tag import Okt
t = Okt()

t.nouns('한국어 분석. 시작합니다. 그렇습니다.')
t.morphs('한국어 분석. 시작합니다. 그렇습니다.')
t.pos('한국어 분석. 시작합니다. 그렇습니다.')
# Out:
# [('한국어', 'Noun'),
#  ('분석', 'Noun'),
#  ('.', 'Punctuation'),
#  ('시작', 'Noun'),
#  ('합니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('그렇습니다', 'Adjective'),
#  ('.', 'Punctuation')]

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# %%
text = open("alice.txt").read()
stopwords = set(STOPWORDS)
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
# ...

# %%
wc = WordCloud(background_color='white',max_words=1000, stopwords=stopwords, mask=alice_mask)
wc = wc.generate(text)
wc.words_
# Out:
# {'Alice': 1.0,
#  'little': 0.29508196721311475,
#  'one': 0.27595628415300544,
#  'know': 0.2459016393442623,
#  'went': 0.226775956284153,
#  'thing': 0.2185792349726776,
#  'time': 0.2103825136612022,
#  'Queen': 0.20765027322404372,
#  'see': 0.1830601092896175,
#  'King': 0.17486338797814208,
#  'well': 0.1721311475409836,
#  'now': 0.16393442622950818,
#  'head': 0.16393442622950818,
#  'began': 0.15846994535519127,
#  'way': 0.1557377049180328,
#  'Hatter': 0.1557377049180328,
#  'Mock Turtle': 0.15300546448087432,
#  'say': 0.15027322404371585,
#  'Gryphon': 0.15027322404371585,
#  'think': 0.1448087431693989,
#  'quite': 0.14207650273224043,
#  'much': 0.13934426229508196,
#  'first': 0.13934426229508196,
#  'thought': 0.1366120218579235,
#  'go': 0.1366120218579235,
#  'come': 0.13114754098360656,
#  'never': 0.1284153005464481,
#  'voice': 0.12568306010928962,
#  'looked': 0.12295081967213115,
#  'got': 0.12295081967213115,
#  'must': 0.12021857923497267,
# ...

# %%
stopwords.add("said")

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,15))
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
alice_mask = np.array(Image.open('09. alice_mask.png'))
plt.imshow(alice_mask, cmap = plt.cm.gray)
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()
